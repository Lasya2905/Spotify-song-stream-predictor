# %% [markdown]
# <a href="https://colab.research.google.com/github/Lasya2905/Spotify-song-stream-predictor/blob/main/Spotify_Songs_Stream_Prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install pandas scikit-learn

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
import math
try:
    df = pd.read_csv('/content/spotify-2023.csv', encoding='ISO-8859-1')
    print("Dataset loaded successfully.")
except Exception as e:
    print(f"Error loading dataset: {e}")
    exit()
y_pred = model.predict(X_test_scaled)
mse = mean_squared_error(y_test, y_pred)
rmse = math.sqrt(mse)
r2 = r2_score(y_test, y_pred)
print(f"Mean Squared Error (MSE): {mse:,.0f}")
print(f"Root Mean Squared Error (RMSE): {rmse:,.0f}")
print(f"R-squared: {r2:.3f}")
plt.figure(figsize=(10, 6))
plt.scatter(y_test, y_pred)
plt.plot([0, max(y_test)], [0, max(y_test)], '--r', label='Appr prediction')
plt.xlabel('Actual Streams')
plt.ylabel('Predicted Streams')
plt.title('Actual vs Predicted Streams')
plt.legend()
plt.show()
print("\nPrediction Result :")
print("It predicts a song's streams based on its characteristics.")
sample_index = np.random.randint(0, len(X_test))
sample_features = X_test_scaled[sample_index].reshape(1, -1)
actual_streams = y_test.iloc[sample_index]
predicted_streams = model.predict(sample_features)[0]
try:
    sample_track_name = df.loc[y_test.index[sample_index], 'track_name']
    print(f"\nFor the song '{sample_track_name}',")
except KeyError:
    print("\nFor a sample song,")
print(f"Estimated streams: {predicted_streams:,.0f}")
print(f"It guesses based on the song's beat and how danceable it is.")
print(f"(Actual streams: {actual_streams:,.0f})")
# Out:
# Dataset loaded successfully.
# Mean Squared Error (MSE): 44,263,454,023,501,632
# Root Mean Squared Error (RMSE): 210,388,816
# R-squared: 0.819
# Prediction Result :
# It predicts a song's streams based on its characteristics.
#
# For the song 'Thousand Miles',
# Estimated streams: 217,708,508
# It guesses based on the song's beat and how danceable it is.
# (Actual streams: 244,741,137)
